# %% [markdown]
# <a href="https://colab.research.google.com/github/meetdarbar93/AI-ML-Internship/blob/main/Day7/Day7_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Linear Regression
#
# – Used Salary dataset
#
# – Trained a Linear Regression model
#
# – Calculated MAE, MSE, R²
#
# – Plotted the best-fit line
#
#
#
# Task 2: Logistic Regression (No Scaling)
#
# – Used Iris dataset
#
# – Applied label encoding
#
# – Trained Logistic Regression
#
# – Showed classification report and confusion matrix
#
#
#
# Task 3: Effect of Scaling
#
# – Trained Logistic Regression with and without scaling
#
# – Accuracy improved after scaling
#
#
#
# Task 4: Decision Boundary
#
# – Plotted decision boundary using scaled features
#
#
#
# Task 5: Model Comparison
#
# – Compared Linear vs Logistic Regression and saved CSV
